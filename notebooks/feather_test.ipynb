# %%
import pandas as pd

# %%
df = pd.read_csv('https://www.arcgis.com/sharing/rest/content/items/f10774f1c63e40168479a1feb6c7ca74/data')

# %%
df.to_feather('RKI_COVID19.ftr')

# %%
df_ftr = pd.read_feather('RKI_COVID19.ftr')

# %%
df_ftr.head()
# Out:
#    FID  IdBundesland          Bundesland     Landkreis Altersgruppe  \
# 0    1             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 1    2             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 2    3             1  Schleswig-Holstein  SK Flensburg      A15-A34
# 3    4             1  Schleswig-Holstein  SK Flensburg      A35-A59
# 4    5             1  Schleswig-Holstein  SK Flensburg      A15-A34
#
#   Geschlecht  AnzahlFall  AnzahlTodesfall           Meldedatum  IdLandkreis  \
# 0          M           1                0  2020/10/28 00:00:00         1001
# 1          M           1                0  2020/03/19 00:00:00         1001
# 2          M           1                0  2020/03/21 00:00:00         1001
# 3          M           1                0  2020/03/14 00:00:00         1001
# 4          M           1                0  2020/03/14 00:00:00         1001
#
#               Datenstand  NeuerFall  NeuerTodesfall             Refdatum  \
# ...

# %%
df.to_csv('RKI_COVID19.xz')

# %%
df.to_feather('RKI_COVID19_zstd.ftr', compression='zstd', compression_level=9)
